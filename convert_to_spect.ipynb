# %% [markdown]
# <a href="https://colab.research.google.com/github/vydiep/MLProject/blob/main/convert_to_spect.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!/usr/bin/env python3

from pathlib import Path
from sys import argv
from scipy import signal
from scipy.io import wavfile
import numpy as np
import matplotlib.pyplot as plt

def create_spectrograms(folder_path):
    files = [file for file in folder_path.iterdir() if file.is_file() and ("wav" in file.name)]
    for (x, file) in enumerate(files):
        without_file_extension = file.name[:-4]
        resolved = Path(f'{folder_path}/{without_file_extension}')
        if (Path(f'{resolved}.png').is_file() == False):
            print('making spectro for', resolved)
            sample_rate, samples = wavfile.read(file)
            frequencies, times, spectrogram = signal.spectrogram(samples, sample_rate)
            plt.pcolormesh(np.log(spectrogram))
            plt.axis('off')
            plt.ylim(ymax=40)
            # plt.show() # Uncomment if you want to check out the plot.
            plt.savefig(f'{resolved}.png', transparent=True)
            # saves the file as a .png with transparent background (no border)

# %%
path = Path("/content/drive/Shareddrives/MLProject/MusicNet/musicnet/musicnet/test_data")
create_spectrograms(path)
# Out:
# making spectro for /content/drive/Shareddrives/MLProject/MusicNet/musicnet/musicnet/test_data/1759
# <ipython-input-2-54ef89227e97>:19: RuntimeWarning: divide by zero encountered in log
#   plt.pcolormesh(np.log(spectrogram))
# making spectro for /content/drive/Shareddrives/MLProject/MusicNet/musicnet/musicnet/test_data/1819
# making spectro for /content/drive/Shareddrives/MLProject/MusicNet/musicnet/musicnet/test_data/2106
# making spectro for /content/drive/Shareddrives/MLProject/MusicNet/musicnet/musicnet/test_data/2191
# making spectro for /content/drive/Shareddrives/MLProject/MusicNet/musicnet/musicnet/test_data/2298
# making spectro for /content/drive/Shareddrives/MLProject/MusicNet/musicnet/musicnet/test_data/2303
# making spectro for /content/drive/Shareddrives/MLProject/MusicNet/musicnet/musicnet/test_data/2382
# making spectro for /content/drive/Shareddrives/MLProject/MusicNet/musicnet/musicnet/test_data/2416
# making spectro for /content/drive/Shareddrives/MLProject/MusicNet/musicnet/musicnet/test_data/2556
# making spectro for /content/drive/Shareddrives/MLProject/MusicNet/musicnet/musicnet/test_data/2628

# %%
import os
print(os.getpid())
# Out:
# 21700

# %%
# !kill 21700
