# %% [markdown]
# <a href="https://colab.research.google.com/github/vydiep/MLProject/blob/main/RNN_Tutorial_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install keras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras in /usr/local/lib/python3.9/dist-packages (2.12.0)

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras
import matplotlib.pyplot as plt

# %%
DATA_PATH = "/content/drive/Shareddrives/MLProject/MusicNet/data.json"

# %%
def load_data(data_path):
    """Loads training dataset from json file.
        :param data_path (str): Path to json file containing data
        :return X (ndarray): Inputs
        :return y (ndarray): Targets
    """

    with open(data_path, "r") as fp:
        data = json.load(fp)

    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y

# %%
def plot_history(history):
    """Plots accuracy/loss for training/validation set as a function of the epochs
        :param history: Training history of model
        :return:
    """

    fig, axs = plt.subplots(2)

    # create accuracy sublpot
    axs[0].plot(history.history["accuracy"], label="train accuracy")
    axs[0].plot(history.history["val_accuracy"], label="test accuracy")
    axs[0].set_ylabel("Accuracy")
    axs[0].legend(loc="lower right")
    axs[0].set_title("Accuracy eval")

    # create error sublpot
    axs[1].plot(history.history["loss"], label="train error")
    axs[1].plot(history.history["val_loss"], label="test error")
    axs[1].set_ylabel("Error")
    axs[1].set_xlabel("Epoch")
    axs[1].legend(loc="upper right")
    axs[1].set_title("Error eval")

    plt.show()

# %%
def prepare_datasets(test_size, validation_size):
    """Loads data and splits it into train, validation and test sets.
    :param test_size (float): Value in [0, 1] indicating percentage of data set to allocate to test split
    :param validation_size (float): Value in [0, 1] indicating percentage of train set to allocate to validation split
    :return X_train (ndarray): Input training set
    :return X_validation (ndarray): Input validation set
    :return X_test (ndarray): Input test set
    :return y_train (ndarray): Target training set
    :return y_validation (ndarray): Target validation set
    :return y_test (ndarray): Target test set
    """

    # load data
    X, y = load_data(DATA_PATH)

    # create train, validation and test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    return X_train, X_validation, X_test, y_train, y_validation, y_test

# %%
def build_model(input_shape):
    """Generates RNN-LSTM model
    :param input_shape (tuple): Shape of input set
    :return model: RNN-LSTM model
    """

    # build network topology
    model = keras.Sequential()

    # 2 LSTM layers
    model.add(keras.layers.LSTM(64, input_shape=input_shape, return_sequences=True))
    model.add(keras.layers.LSTM(64))

    # dense layer
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer
    model.add(keras.layers.Dense(2, activation='softmax'))

    return model

# %%
# get train, validation, test splits
X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

# create network
input_shape = (X_train.shape[1], X_train.shape[2]) # 130, 13
model = build_model(input_shape)

# compile model
optimiser = keras.optimizers.Adam(learning_rate=0.0001)
model.compile(optimizer=optimiser,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.summary()

# train model
history = model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

# plot accuracy/error for training and validation
plot_history(history)

# evaluate model on test set
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 130, 64)           19968
#
#  lstm_1 (LSTM)               (None, 64)                33024
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 57,282
# Trainable params: 57,282
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 62/62 [==============================] - 20s 184ms/step - loss: 0.6985 - accuracy: 0.5045 - val_loss: 0.6903 - val_accuracy: 0.5131
# Epoch 2/30
# 62/62 [==============================] - 12s 192ms/step - loss: 0.6876 - accuracy: 0.5465 - val_loss: 0.6864 - val_accuracy: 0.5333
# Epoch 3/30
# 62/62 [==============================] - 12s 197ms/step - loss: 0.6794 - accuracy: 0.5667 - val_loss: 0.6826 - val_accuracy: 0.5495
# Epoch 4/30
# 62/62 [==============================] - 12s 187ms/step - loss: 0.6718 - accuracy: 0.5838 - val_loss: 0.6788 - val_accuracy: 0.5354
# Epoch 5/30
# 62/62 [==============================] - 11s 175ms/step - loss: 0.6551 - accuracy: 0.6222 - val_loss: 0.6675 - val_accuracy: 0.5616
# Epoch 6/30
# 62/62 [==============================] - 11s 175ms/step - loss: 0.6423 - accuracy: 0.6288 - val_loss: 0.6513 - val_accuracy: 0.5939
# Epoch 7/30
# 62/62 [==============================] - 13s 210ms/step - loss: 0.6193 - accuracy: 0.6636 - val_loss: 0.6351 - val_accuracy: 0.6141
# Epoch 8/30
# 62/62 [==============================] - 12s 196ms/step - loss: 0.6060 - accuracy: 0.6677 - val_loss: 0.6305 - val_accuracy: 0.6061
# Epoch 9/30
# 62/62 [==============================] - 12s 198ms/step - loss: 0.5869 - accuracy: 0.6955 - val_loss: 0.6246 - val_accuracy: 0.6283
# Epoch 10/30
# 62/62 [==============================] - 11s 176ms/step - loss: 0.5715 - accuracy: 0.7051 - val_loss: 0.6176 - val_accuracy: 0.6384
# Epoch 11/30
# 62/62 [==============================] - 11s 176ms/step - loss: 0.5588 - accuracy: 0.7106 - val_loss: 0.6146 - val_accuracy: 0.6465
# Epoch 12/30
# 62/62 [==============================] - 12s 188ms/step - loss: 0.5492 - accuracy: 0.7207 - val_loss: 0.6379 - val_accuracy: 0.6485
# Epoch 13/30
# 62/62 [==============================] - 12s 197ms/step - loss: 0.5557 - accuracy: 0.7146 - val_loss: 0.6136 - val_accuracy: 0.6364
# Epoch 14/30
# 62/62 [==============================] - 12s 191ms/step - loss: 0.5369 - accuracy: 0.7136 - val_loss: 0.6142 - val_accuracy: 0.6606
# Epoch 15/30
# 62/62 [==============================] - 10s 165ms/step - loss: 0.5188 - accuracy: 0.7379 - val_loss: 0.6083 - val_accuracy: 0.6646
# Epoch 16/30
# 62/62 [==============================] - 12s 189ms/step - loss: 0.5130 - accuracy: 0.7364 - val_loss: 0.6113 - val_accuracy: 0.6646
# Epoch 17/30
# 62/62 [==============================] - 12s 197ms/step - loss: 0.5068 - accuracy: 0.7470 - val_loss: 0.6197 - val_accuracy: 0.6545
# Epoch 18/30
# 62/62 [==============================] - 12s 197ms/step - loss: 0.5014 - accuracy: 0.7510 - val_loss: 0.6069 - val_accuracy: 0.6646
# Epoch 19/30
# 62/62 [==============================] - 11s 180ms/step - loss: 0.4971 - accuracy: 0.7460 - val_loss: 0.6053 - val_accuracy: 0.6687
# Epoch 20/30
# 62/62 [==============================] - 11s 169ms/step - loss: 0.4907 - accuracy: 0.7540 - val_loss: 0.6391 - val_accuracy: 0.6404
# Epoch 21/30
# 62/62 [==============================] - 12s 197ms/step - loss: 0.4831 - accuracy: 0.7697 - val_loss: 0.6278 - val_accuracy: 0.6646
# Epoch 22/30
# 62/62 [==============================] - 12s 197ms/step - loss: 0.4718 - accuracy: 0.7737 - val_loss: 0.6220 - val_accuracy: 0.6687
# Epoch 23/30
# 62/62 [==============================] - 12s 197ms/step - loss: 0.4804 - accuracy: 0.7606 - val_loss: 0.5941 - val_accuracy: 0.6727
# Epoch 24/30
# 62/62 [==============================] - 11s 175ms/step - loss: 0.4693 - accuracy: 0.7692 - val_loss: 0.6111 - val_accuracy: 0.6646
# Epoch 25/30
# 62/62 [==============================] - 11s 175ms/step - loss: 0.4583 - accuracy: 0.7768 - val_loss: 0.6662 - val_accuracy: 0.6768
# Epoch 26/30
# 62/62 [==============================] - 12s 198ms/step - loss: 0.4479 - accuracy: 0.7813 - val_loss: 0.6637 - val_accuracy: 0.6606
# Epoch 27/30
# 62/62 [==============================] - 12s 198ms/step - loss: 0.4594 - accuracy: 0.7753 - val_loss: 0.6304 - val_accuracy: 0.6828
# Epoch 28/30
# 62/62 [==============================] - 12s 197ms/step - loss: 0.4473 - accuracy: 0.7788 - val_loss: 0.6235 - val_accuracy: 0.6768
# Epoch 29/30
# 62/62 [==============================] - 11s 171ms/step - loss: 0.4402 - accuracy: 0.7818 - val_loss: 0.6496 - val_accuracy: 0.6667
# Epoch 30/30
# 62/62 [==============================] - 11s 172ms/step - loss: 0.4302 - accuracy: 0.7939 - val_loss: 0.6284 - val_accuracy: 0.6869
# 26/26 - 1s - loss: 0.6052 - accuracy: 0.6970 - 1s/epoch - 53ms/step
#
# Test accuracy: 0.6969696879386902
